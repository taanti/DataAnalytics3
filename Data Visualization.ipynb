# %% [markdown]
# # Data Visualization
#
# Data visualization is the process of transforming data into visual representations, such as charts, graphs, or maps, to help understand and analyze data effectively.
#
# Four common types or categories of data visualization:
#
# - **Comparison**: This type of visualization is used to compare different data points, such as comparing sales figures between different months or comparing the performance of different products.  -
# - **Composition**: Compositional visualizations show how the whole is divided into parts. Examples are a pie chart or a stacked bar chart, where each segment represents a proportion of the whole.
# - **Relationship**: Relationship visualizations depict relationships or correlations between variables. This can include scatter plots, network diagrams, or chord diagrams, which show how various elements relate to each other.
# - **Spatial**: Spatial visualizations make use of geographic information to represent data. An example is a map or heat map, which displays data based on geographic location or spatial relationships.

# %% [markdown]
# # There are Several Types of Charts and what they are used for

# %% [markdown]
# - **Bar Chart (Comparison)**:
#   - **Vertical**: Suitable for small data with multiple categories.b
#
#     ![Vertical Bar Chart.png](attachment:feba2499-19a6-4a9a-9080-be05e5a6ccd8.png)
#
#     Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/hutan-untuk-masa-depan)
#
#   - **Horizontal**: Ideal for big data between categories.
#
#     ![Horizontal Bar Chart.png](attachment:c643a52e-bc59-4b74-8bfb-22f560e79b45.png)
#
#     Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/potret-permasalahan-remaja-di-jawa-barat)
#
# - **Line Chart (Comparison)**:
#   - **Single Line**: Used for comparing one category over time.
#
#     ![Single Line Chart.png](attachment:426e245e-04f6-4170-afbe-9a452f2c9b7e.png)
#
#     Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/jabar-juara-swasembada-ayam-pedaging-nasional---jdvf-competition-2022)
#
#   - **Multiple Lines**: Used for comparing two or more categories over time.
#
#     ![Multiple Line Chart.png](attachment:b6e16458-c239-43b1-a01b-6df3117944e8.png)
#
#     Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/penguatan-kinerja-keuangan-pemprov-jabar-melalui-optimalisasi-pajak-kendaraan-bermotor-pemprov-jawa-barat---jdvf-competition-2022)

# %% [markdown]
# - **Stacked Bar Chart (Composition & Comparison)**: Shows components within a category. Can be used over time; both relative and absolute differences matter.
#
#     ![Stacked Bar Chart.png](attachment:0e7597b8-69fc-4060-b828-c06a8617d6d6.png)
#
#     Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/visualisasi-desa-yang-mengalami-pencemaran-lingkungan-di-provinsi-jawa-barat-tahun-2020)
#
# - **Stacked 100% Bar Chart (Composition & Comparison)**: Shows components within a category in percentage. Focuses on the contribution of each component. Can be used over time; only relative differences matter.
#
#     ![Stacked 100% Bar Chart.png](attachment:b655195c-d611-4b06-b9c7-4f1a0c491617.png)
#
#     Data Source: [Source](https://ironic3d.com.au/categorical-charts/power-bi-100-stacked-bar-chart)
#
# - **Pie Chart (Composition)**: Static composition. Useful for fewer than 5 categories. Represents the share of the total.
#
#     ![Pie Chart.png](attachment:a3e76a7b-f064-4016-9201-10895885497d.png)
#
#     Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/visualisasi-jumlah-fasilitas-kesehatan-di-provinsi-jawa-barat-tahun-2020)
#
# - **Tree Map Chart (Composition)**: Static composition. Accumulation to total. Absolute difference matters.
#
#     ![Tree Map.png](attachment:2a7f482e-7325-42d3-893a-5e20fdfb9752.png)
#
#     Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/melihat-kesempatan-kerja-di-jawa-barat)

# %% [markdown]
# - **Scatter Plot (Relationship)**: Combine relationship/correlation between X and Y with a scatter plot showing all data points.
#
#   ![Scatter Plot.png](attachment:c4608efd-48dd-4d0b-bf87-cbb3eeb3ef8c.png)
#
#   Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/ubi-jalar---komoditas-ekspor-unggulan-jawa-barat)
#
# - **Spatial Map (Relationship)**: For displaying quantitative information on a map, especially when defined regions are crucial and to gain an overview of distribution across geographic locations, consider using choropleth maps.
#
#   ![Spatial Chart.png](attachment:b964b921-26c3-435d-9506-b4d324110bc6.png)
#
#   Data Source: [Source](https://opendata.jabarprov.go.id/id/visualisasi/west-java-through-the-lens-of-sdg-4-quality-education---jdvf-competition-2022)
